# %% [markdown]
# ## 1.

# %%
## Matplotlib is a python library used to create 2D graphs and plots by using python scripts.
## It has a module named pyplot which makes things easy for plotting by providing feature to control line styles, font properties, formatting axes etc.

# %%
## 1.Bar graph 2.histogram 3.Scatter plot 4.Area plot 5.Pie plot

# %% [markdown]
# ## 2

# %%
# a graph in which the values of two variables are plotted along two axes, the pattern of the resulting points revealing any correlation present.

# %%
import numpy as np
import matplotlib.pyplot as mpt

# %%
x=3+np.random.normal(0,2,50)
y=3+np.random.normal(0,2,len(x))

# %%
x
# Out:
# array([ 3.91541076,  1.7046269 ,  4.71388467,  1.38070491,  3.21612519,
#         2.9827801 ,  3.0268247 ,  0.48936673,  5.54810755,  3.2720548 ,
#         4.30839389, -1.82540852,  0.86719137,  0.7881262 ,  2.7238409 ,
#         3.15983708,  1.19490763,  1.33157152,  2.99149692,  4.23724458,
#         1.93319658,  1.21352736,  3.02468377,  1.17250163,  3.34540741,
#        -0.19770565,  3.24414532,  2.97650241, -0.70043819,  4.2885195 ,
#         1.1121856 ,  0.77795103,  2.78437505,  1.74886912,  3.28429143,
#         2.31066765,  1.07424847,  5.4783701 ,  3.55971488,  1.91841731,
#         1.79829089,  0.42354522,  2.10685201,  4.26997632,  3.56985631,
#         3.78766489,  9.49677189,  6.41555162,  0.9700369 ,  6.77424953])

# %%
y
# Out:
# array([ 5.82604477,  3.37945118, -0.11677903,  3.26378396,  2.02720241,
#         2.16502697, -0.36077841,  5.07891116,  2.83050324,  2.16896324,
#         0.62124215,  3.99345734,  6.04939815,  3.0435509 ,  2.10565495,
#         5.4699853 ,  3.7666266 ,  4.22093733,  2.92257211,  3.5970277 ,
#         0.4171494 ,  3.92703217,  3.98110602, -0.32202247,  2.36048583,
#         0.17948156,  6.50163035,  3.19143974,  2.89010798,  3.86838575,
#         3.58583811,  1.78313051,  3.31797009,  4.65850347,  3.54150991,
#         3.05537876,  6.63850904, -0.35555499,  3.33213035,  1.57266406,
#         3.6903424 ,  7.00323042,  3.12675402,  4.15637553,  2.40262116,
#         3.79750693,  3.220501  ,  6.19173346,  5.44598817,  2.62312351])

# %%
mpt.scatter(x,y)
mpt.xlabel("x axis")
mpt.ylabel("y axis")
mpt.title("Graph of x and y")
# Out:
# Text(0.5, 1.0, 'Graph of x and y')

# %% [markdown]
# ## 3.

# %%
## subplot() function adds subplot to a current figure at the specified grid position. 
## It is similar to the subplots() function however unlike subplots() it adds one subplot at a time.
## So to create multiple plots you will need several lines of code with the subplot() function.
## Another drawback of the subplot function is that it deletes the preexisting plot on your figure.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([0,1,2,3,4,5])

ax=plt.subplots(2,2)
y1=np.array([0,100,200,300,400,500])
y2=np.array([50,20,40,20,60,70])
y3=np.array([10,20,30,40,50,60])
y4=np.array([200,350,250,550,450,150])
y=np.array([y1,y2,y3,y4])

for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.plot(x, y[i])

# %% [markdown]
# ## 4.

# %%
## Bar plots are a type of data visualization used to represent data in the form of rectangular bars.

# %%
company=np.array(["Apple","Microsoft","Google","AMD"])
profit=np.array([3000,8000,1000,10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## 5.

# %%
## Box plots are used to show distributions of numeric data values, especially when you want to compare them between multiple groups.

# %%
box1=np.random.normal(100,10,200)
box2=np.random.normal(90,20,200)

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6522a00df0>,
#   <matplotlib.lines.Line2D at 0x7f6522a032b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6522a01c00>,
#   <matplotlib.lines.Line2D at 0x7f65232cd210>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6522a02440>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6522a01810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6522a03e20>],
#  'means': []}

# %%
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6522bb3a60>,
#   <matplotlib.lines.Line2D at 0x7f6522bb3070>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6522bb29e0>,
#   <matplotlib.lines.Line2D at 0x7f652386fb50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6522bb23b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f65235cd240>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6523909e70>],
#  'means': []}
